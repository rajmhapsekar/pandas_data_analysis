# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("C:/Users/rajmh/OneDrive/Desktop/pandas/ram.txt")

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\r\nAlexisborough, NE ...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\r\nSouth John, TN...  28 rn       PM
# 2                    Unit 0065 Box 5052\r\nDPO AP 27450  94 vE       PM
# 3               7780 Julia Fords\r\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\r\nNew Cynthia, TX...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995    966 Castaneda Locks\r\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\r\nNorth Edwardburgh,...  41 JY       AM
# 9997            Unit 4434 Box 6343\r\nDPO AE 28026-0283  74 Zh       AM
# 9998             0096 English Rest\r\nRoystad, IA 12457  74 cL       PM
# 9999   40674 Barrett Stravenue\r\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
## top 10 rows of df

# %%
df.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\r\nAlexisborough, NE ...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\r\nSouth John, TN...  28 rn       PM
# 2                 Unit 0065 Box 5052\r\nDPO AP 27450  94 vE       PM
# 3            7780 Julia Fords\r\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\r\nNew Cynthia, TX...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
## last 10 rows of the data set

# %%
df.tail(10)
# Out:
#                                                 Address    Lot AM or PM  \
# 9990  75731 Molly Springs\r\nWest Danielle, VT 96934...  93 ty       PM
# 9991            PSC 8165, Box 8498\r\nAPO AP 60327-0346  50 dA       AM
# 9992  885 Allen Mountains Apt. 230\r\nWallhaven, LA ...  40 vH       PM
# 9993  7555 Larson Locks Suite 229\r\nEllisburgh, MA ...  72 jg       PM
# 9994     6276 Rojas Hollow\r\nLake Louis, WY 56410-7837  93 Ex       PM
# 9995    966 Castaneda Locks\r\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\r\nNorth Edwardburgh,...  41 JY       AM
# 9997            Unit 4434 Box 6343\r\nDPO AE 28026-0283  74 Zh       AM
# 9998             0096 English Rest\r\nRoystad, IA 12457  74 cL       PM
# 9999   40674 Barrett Stravenue\r\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9990  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_4;...
# 9991  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# ...

# %%
## check data type of each column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
df.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %%
## how many rows and columns in df

# %%
df.shape
# Out:
# (10000, 14)

# %%
print('number of rows',df.shape[0])
print('number of columns',df.shape[1])
# Out:
# number of rows 10000
# number of columns 14

# %%
## highest and lowest purchase price

# %%
df['Purchase Price'].max()
#df['Purchase Price'].min()
# Out:
# 99.99

# %%
df['Purchase Price'].min()
# Out:
# 0.0

# %%
## avg purchase price

# %%
df['Purchase Price'].mean()
# Out:
# 50.347302

# %%
### how many people have french 'fr' as their language

# %%
df['Language'].unique()
# Out:
# array(['el', 'fr', 'de', 'es', 'ru', 'pt', 'zh', 'en', 'it'], dtype=object)

# %%
df['Language'].value_counts()
# Out:
# Language
# de    1155
# ru    1155
# el    1137
# pt    1118
# en    1098
# fr    1097
# es    1095
# it    1086
# zh    1059
# Name: count, dtype: int64

# %%
len(df[df['Language']=='fr'])
# Out:
# 1097

# %%
df[df['Language']=='fr'].count()
# Out:
# Address             1097
# Lot                 1097
# AM or PM            1097
# Browser Info        1097
# Company             1097
# Credit Card         1097
# CC Exp Date         1097
# CC Security Code    1097
# CC Provider         1097
# Email               1097
# Job                 1097
# IP Address          1097
# Language            1097
# Purchase Price      1097
# dtype: int64

# %%
## job title which contain Engineer

# %%
len(df[df['Job'].str.contains('engineer',case=False)])
# Out:
# 984

# %%
## find email id of the person with following ip addres 132.207.160.22

# %%
df[df['IP Address']=='132.207.160.22'][['IP Address','Email']]
# Out:
#        IP Address                           Email
# 2  132.207.160.22  amymiller@morales-harrison.com

# %%
df.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %%
## how many people have master card as a cc provider and made purchase above 50?

# %%
len(df[(df['CC Provider']=='Mastercard') & (df['Purchase Price']>50)])
# Out:
# 405

# %%
## find email of the person with following cc number= 4664825258997302

# %%
df[df['Credit Card']==4664825258997302][['Credit Card','Email']]
# Out:
#            Credit Card              Email
# 9992  4664825258997302  bberry@wright.net

# %%
## how many people purchase during the am and pm

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
df['AM or PM'].value_counts()
# Out:
# AM or PM
# PM    5068
# AM    4932
# Name: count, dtype: int64

# %%
## how many people have credit card that have expiry in 2020

# %%
df['CC Exp Date']
# Out:
# 0       02/20
# 1       11/18
# 2       08/19
# 3       02/24
# 4       10/25
#         ...
# 9995    03/22
# 9996    07/25
# 9997    05/21
# 9998    11/17
# 9999    02/19
# Name: CC Exp Date, Length: 10000, dtype: object

# %%
def fun():
    count=0
    for i in df['CC Exp Date']:
        if i.split('/')[1]=='20':
           count=count+1
    print(count)

# %%
fun()
# Out:
# 988

# %%
len(df[df['CC Exp Date'].apply(lambda x:x[3:]=='20')])
# Out:
# 988

# %%
## top 5 most popular email provider

# %%
df['Email']
# Out:
# 0                    pdunlap@yahoo.com
# 1                   anthony41@reed.com
# 2       amymiller@morales-harrison.com
# 3          brent16@olson-robinson.info
# 4          christopherwright@gmail.com
#                      ...
# 9995            iscott@wade-garner.com
# 9996                mary85@hotmail.com
# 9997                 tyler16@gmail.com
# 9998           elizabethmoore@reid.net
# 9999             rachelford@vaughn.com
# Name: Email, Length: 10000, dtype: object

# %%
l1=[]
for i in df['Email']:
    l1.append(i.split('@')[1])

# %%
l1
# Out:
# ['yahoo.com',
#  'reed.com',
#  'morales-harrison.com',
#  'olson-robinson.info',
#  'gmail.com',
#  'gmail.com',
#  'yahoo.com',
#  'parks.info',
#  'rasmussen.com',
#  'hunt-huerta.com',
#  'hotmail.com',
#  'coleman.com',
#  'hotmail.com',
#  'yahoo.com',
#  'yahoo.com',
#  'yahoo.com',
#  'wilson.com',
#  'hall.com',
#  'yahoo.com',
#  'gmail.com',
#  'smith.info',
#  'hotmail.com',
#  'gmail.com',
#  'gardner-meadows.com',
#  'yahoo.com',
#  'mooney.com',
#  'gmail.com',
#  'hotmail.com',
#  'yahoo.com',
#  'yahoo.com',
#  'hotmail.com',
#  'hotmail.com',
#  'atkinson.com',
#  'yahoo.com',
#  'carey-davis.com',
#  'mcdowell.com',
#  'walsh.com',
#  'frederick.info',
#  'boyd-english.org',
#  'wells-carlson.info',
#  'dickerson.com',
#  'yahoo.com',
#  'gmail.com',
#  'martinez-thomas.com',
#  'yahoo.com',
#  'chambers.com',
#  'gmail.com',
#  'glenn.org',
#  'allen.com',
#  'gmail.com',
#  'obrien.org',
#  'cook-castillo.com',
#  'hotmail.com',
#  'yahoo.com',
#  'hotmail.com',
# ...

# %%
df['temp']=l1

# %%
df['temp']
# Out:
# 0                  yahoo.com
# 1                   reed.com
# 2       morales-harrison.com
# 3        olson-robinson.info
# 4                  gmail.com
#                 ...
# 9995         wade-garner.com
# 9996             hotmail.com
# 9997               gmail.com
# 9998                reid.net
# 9999              vaughn.com
# Name: temp, Length: 10000, dtype: object

# %%
df['temp'].value_counts().head(5)
# Out:
# temp
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: count, dtype: int64

# %%
df['Email'].apply(lambda x:x.split('@')[1]).value_counts().head(5)
# Out:
# Email
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: count, dtype: int64
